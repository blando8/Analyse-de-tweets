# %%
import tweepy
import time
from datetime import datetime, timedelta
from json import dumps
import seaborn as sns
import json
import pandas as pd

# %%
df0 = pd.read_excel("data Général.xls")
df1 = pd.read_excel("data03_juin.xls")
df2 = pd.read_excel("data05_juin.xls")
df3 = pd.read_excel("data06_juin.xls")
df4 = pd.read_excel("data06_juin.xls")
df5 = pd.read_excel("data07_juin.xls")
df6 = pd.read_excel("data08_juin.xls")
df7 = pd.read_excel("data09_juin.xls")
df8 = pd.read_excel("data12_juin.xls")
df9 = pd.read_excel("data13_juin.xls")
df10 = pd.read_excel("data14_juin.xls")
df11 = pd.read_excel("data15_juin.xls")
df12 = pd.read_excel("data16_juin.xls")
df13 = pd.read_excel("data19_juin.xls")
df14 = pd.read_excel("data20_juin.xls")
df15 = pd.read_excel("data21_juin.xls")
df16 = pd.read_excel("data22_juin.xls")
df17 = pd.read_excel("data24_juin.xls")
df18 = pd.read_excel("data25_juin.xls")
df19 = pd.read_excel("data26_juin.xls")
df20 = pd.read_excel("data27_juin.xls")
df21 = pd.read_excel("data28_juin.xls")
df22 = pd.read_excel("data29_juin.xls")
df23 = pd.read_excel("data30_juin.xls")
df24 = pd.read_excel("data01_juillet.xls")
df25 = pd.read_excel("data02_juillet.xls")
df26 = pd.read_excel("data02_juillet_nuit.xls")
df27 = pd.read_excel("data05_juillet_nuit.xls")
df28 = pd.read_excel("data05_juin_nuit.xls")
df29 = pd.read_excel("data06_juillet_nuit.xls")
df30 = pd.read_excel("data07_juillet_nuit.xls")
df31 = pd.read_excel("data08_juillet_nuit.xls")
df32 = pd.read_excel("data09_juillet_nuit.xls")
df33 = pd.read_excel("data10_juillet_nuit.xls")
df34 = pd.read_excel("data11_juillet_nuit.xls")
df35 = pd.read_excel("data13_juillet_nuit.xls")
df36 = pd.read_excel("data13_juillet_nuite.xls")
df37 = pd.read_excel("data14_juillet.xls")
df38 = pd.read_excel("data15_juillet.xls")
df39 = pd.read_excel("data15_juillet_nuit.xls")
df40 = pd.read_excel("data16_juillet.xls")
df41 = pd.read_excel("data16_juillet_nuit.xls")
df42 = pd.read_excel("data17_juillet.xls")
df43 = pd.read_excel("data18_juillet.xls")
df44 = pd.read_excel("data19_juillet.xls")
df45 = pd.read_excel("data20_juillet.xls")
df46 = pd.read_excel("data21_juillet.xls")

# %%
df = pd.concat([df0,df1, df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,
               df22,df23,df24,df25,df26,df27,df28,df29,df30,df31,df32,df33,df34,df35,df36,df37,df38,df39,df40,df41,
                df42,df43,df44,df45,df46], 
               join = 'inner')

# %%
df
# Out:
#                                                 tweet              user_id  \
# 0   L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 1                                                 NaN           1694150034
# 2                                                 NaN            520783860
# 3   #DocTocToc les PCR Covid pré-op sur asymptotiq...   715919814846451712
# 4   #Doctoctoc un site pr avoir rdv rapide ac derm...   998986853293416448
# ..                                                ...                  ...
# 95                                                NaN           2880654849
# 96                                                NaN            321935279
# 97                                                NaN   789177793221304320
# 98                                                NaN           3133154154
# 99  @dferal44 Chère cousine... Le #Doctoctoc est u...  1239105591806693376
#
# ...

# %%
# Let's drop duplicated rows:
print('Initial size of dataset before dropping duplicated rows:', df.shape)
df.drop_duplicates(keep = False, inplace = True)

print('Current size of dataset after dropping duplicated rows, if any, is:', df.shape)
print(df.head())
# Out:
# Initial size of dataset before dropping duplicated rows: (5282, 26)
# Current size of dataset after dropping duplicated rows, if any, is: (4735, 26)
#                                                tweet             user_id  \
# 0  L’alcool à brûler est-il efficace contre le CO...  976744477745348608
# 1                                                NaN          1694150034
# 2                                                NaN           520783860
# 3  #DocTocToc les PCR Covid pré-op sur asymptotiq...  715919814846451712
# 4  #Doctoctoc un site pr avoir rdv rapide ac derm...  998986853293416448
#
#              user.name           created_at  followers_count     location  \
# 0  𝓝𝓮𝓫𝓾𝓵𝓮𝓾𝓼𝓮  (public)  2020-05-11 17:49:12              266          NaN
# 1   Anne-Claude Danzel  2020-05-11 16:42:38              281          NaN
# 2              océAlaB  2020-05-11 16:19:07              948  petaouchnok
# 3           Pétronille  2020-05-11 16:17:56              777          NaN
# ...

# %%
df
# Out:
#                                                 tweet              user_id  \
# 0   L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 1                                                 NaN           1694150034
# 2                                                 NaN            520783860
# 3   #DocTocToc les PCR Covid pré-op sur asymptotiq...   715919814846451712
# 4   #Doctoctoc un site pr avoir rdv rapide ac derm...   998986853293416448
# ..                                                ...                  ...
# 95                                                NaN           2880654849
# 96                                                NaN            321935279
# 97                                                NaN   789177793221304320
# 98                                                NaN           3133154154
# 99  @dferal44 Chère cousine... Le #Doctoctoc est u...  1239105591806693376
#
# ...

# %%
df = df.drop_duplicates(subset =["tweet_id"])

# %%
df
# Out:
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 41   Bonjour à tous ! Néo interne déçu de mes ECNi,...            577992136
# 42                                          #DocTocToc           2907477543
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #DocTocToc #KineTocToc \nJ’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
df.to_excel("data_final.xls", index = False)

# %%
df = df.drop_duplicates(subset =["text"])
df
# Out:
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   Hello #DocTocToc #Rachiphiles #TeamKiné :\nPte...   911146402289537024
# 41   Bonjour à tous ! Néo interne déçu de mes ECNi,...            577992136
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #DocTocToc #KineTocToc \nJ’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
df['retweet'].fillna(0, inplace = True)
df
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   Hello #DocTocToc #Rachiphiles #TeamKiné :\nPte...   911146402289537024
# ...

# %%
username = df['user.name']
print('No. of distinct locations listed by twitter users is:', len(df['user.name'].value_counts()))
unique_username = df['user.name'].value_counts()

# Remove n.a.
unique_username = pd.DataFrame({'user.name': unique_username.index,
                                'count': unique_username.values})
unique_username.drop(0, inplace = True)

# See top few locations
unique_username.sort_values(by = 'count', ascending = False).head(10)
# Out:
# No. of distinct locations listed by twitter users is: 669
#                    user.name  count
# 1           marguerite dupré     41
# 2                   Oliv Met     35
# 3                 DrNamaskar     19
# 4             Docteur Patate     15
# 5                Docsousleau     14
# 6                       Jedi     14
# 7   DocMarmotte #MasquezVous     13
# 9                    Mr. Fox     12
# 8        Deghilage Christele     12
# 10                        Dr     11

# %%
unique_user_temp = unique_username.drop(list_ind)
count = pd.to_numeric(unique_user_temp['count'])

# %%
unique_user_temp['count'] = count

# %%
unique_user_temp = unique_user_temp.head(8)

# %%
# Plot a bar plot
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16,8))
sns.set_palette('PuBuGn_d')
sns.barplot(x = 'count', y = 'user.name', orient = 'h',data = unique_user_temp)
plt.xlabel('Count')
plt.ylabel('user.name')
plt.title('Top 10 user les plus actifs')
plt.show()

# %%
liste=[]
for index,row in df.iterrows():
    if (row['retweet'] != 0):
        liste.append(row)

# %%
df1=pd.DataFrame(liste)
df1
# Out:
#      tweet              user_id                            user.name  \
# 529    NaN   862359205889617920                        hiposceptique
# 534    NaN            383802907                    Christian Lehmann
# 540    NaN            803065819              R&D Médecine du Travail
# 545    NaN           2996581169                               Ewella
# 550    NaN   959380309526634496                            compagnon
# ..     ...                  ...                                  ...
# 13     NaN            566478974                          DocfromMars
# 15     NaN            438773934  Sebastien Thos #JamaisSansMonMasque
# 19     NaN            136390213                           Kahte🌨️⛈️🌩
# 25     NaN            222536183                                 KPMG
# 44     NaN  1245641055967436800                     Bayarien à faire
#
#               created_at  followers_count                       location  \
# ...

# %%
data = df1.sort_values(by=['retweet_count'], ascending=False)
data
# Out:
#      tweet              user_id         user.name           created_at  \
# 4      NaN           4219901475            Maneki  2020-07-10 14:18:56
# 0      NaN           1076857674     Edna Newhouse  2020-06-16 19:38:17
# 31     NaN   752956761410240512        Biquette13  2020-07-04 18:00:18
# 1      NaN  1033318912484630528          peyrugue  2020-07-18 21:48:12
# 557    NaN           3438196804              MOMO  2020-05-27 08:07:15
# ..     ...                  ...               ...                  ...
# 44     NaN  1245641055967436800  Bayarien à faire  2020-07-20 11:01:13
# 6      NaN  1104510093150822401              zaël  2020-06-28 17:11:10
# 4      NaN  1046087135730839552    Scrabouillette  2020-07-18 21:34:32
# 2      NaN            136390213        Kahte🌨️⛈️🌩  2020-07-17 12:48:59
# 4      NaN            359629371      Mariana Guez  2020-07-14 08:26:56
#
#      followers_count                       location langue  fav  \
# ...

# %%
mycolumns = ['user.name','retweet_count']

# %%
def find_users(df):
    # df: dataframe to look at
    # returns a list of usernames
    
    # Create empty list
    list_users = []
    
    for i in range(0, len(df)):
        users_ith_text = re.findall('@[^\s]+', df.iloc[i,:]['text'])
        # returns a list
        # append to list_users by going through a for-loop:
        for j in range(0, len(users_ith_text)):
            list_users.append(users_ith_text[j])
    
    return list_users

# %%
# Apply on dataframe data['text']
import re
list_users = find_users(df)

mentioned_users_df = pd.DataFrame({
    'mentioned_users': list_users
})

mentioned_users_df.head()
# Out:
#     mentioned_users
# 0          @FZores:
# 1      @rolinette7:
# 2  @ordre_medecins:
# 3        @DrGroquik
# 4     @Asclepios_YT

# %%
mentionedusers = mentioned_users_df.groupby('mentioned_users').size().reset_index(name = 'totalcount').sort_values(by = 'totalcount', ascending = False)
mentionedusers.head()
# Out:
#       mentioned_users  totalcount
# 112         @Fraslin:          17
# 186         @OlivMet:          12
# 273     @doctoctocbot          12
# 79     @DrFranceInde:           9
# 73   @DocteurePATATE:           6

# %%
plt.figure(figsize=(30,8))
sns.set_palette('PuBuGn_d')
sns.barplot(x = 'mentioned_users', y = 'totalcount', data = mentionedusers.head(15))
plt.xlabel('Ceux qui retweetent')
plt.ylabel('Number of times')
plt.title('Top users and how many times they were mentioned in tweets')
plt.show()

# %%
def hashtag (text):
    table_hashtag=[]
    cp_text=text.split()
    for word in cp_text:
        if(word[0]=="#"):
            table_hashtag.append(word)
    return(table_hashtag)

nb_hashtag1=[]
for ligne in df['tweet']:
    result=hashtag(str(ligne).lower())
    for hasht in result:
        nb_hashtag1.append(hasht)

print(nb_hashtag1)
# Out:
# ['#doctoctoc', '#docstoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#covid19', '#notmyresponsibility', '#ccp', '#organizetowin', '#covidiots', '#covididiots', '#covidiot', '#xijinping', '#sociopathinchief', '#friendshipday', '#worldofwarcraft', '#unitednations', '#worldhealthorganization', '#doctoctoc', '#noticia', '#standwithhk', '#hongkong', '#nationalsecuritylaw', '#crimenews', '#promotion', '#covid_19', '#doctoctoc', '#doctoctoc', '#teamkiné', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#mgtoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#msu', '#psytoctoc', '#doctoctoc', '#doctoctoc', '#paspouruneamie', '#doctoctoc', '#covid_19', '#doctoctoc', '#doctoctoc', '#prevention', '#doctoctoc', '#doctoctoc', '#vaccin', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#grippe', '#doctoctoc', '#doctoctoc', '#docstoctoc', '#doctoctoc', '#covid', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#chronique', '#doct
# ...

# %%
nb_hashtag2=[]
for ligne in df['retweet']:
    result=hashtag(str(ligne).lower())
    for hasht in result:
        nb_hashtag2.append(hasht)

print(nb_hashtag2)
# Out:
# ['#doctoctoc', '#doctoctoc', '#certificats', '#covid19', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#pratique', '#legal', '#doctoctoc', '#docstoctoc', '#doctoctoc', '#doctoctoc', '#cvrmtpouruneamie', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#msu', '#psytoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#clubhouse', '#newbell', '#compiègne', '#oise', '#raoultpascontent', '#arminvanbuuren', '#blahblahblah', '#soon', '#nightvibes', '#nightparty', '#nightclubs', '#djm4rs', '#chocolate', '#followｍe', '#tiktok', '#om', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#medecine', '#gastroenterologie', '#internat', '#ecni2020', '#doctoctoc', '#doctoctoc', '#teamkiné', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctoctoc', '#doctocto
# ...

# %%
def nb_occ(mot,tab):
    i=0
    nombre_occ=0
    while (i<len(tab)):
        if(tab[i]==mot):
            nombre_occ=nombre_occ+1
        i=i+1
    return(nombre_occ)

#print(nb_occ("#cvrmtpouruneamie",nb_hashtag2))

# %%
dico_tweet={}
for i in nb_hashtag1:
    dico_tweet[i]=nb_occ(i,nb_hashtag1)
    
dico_retweet={}
for i in nb_hashtag2:
    dico_retweet[i]=nb_occ(i,nb_hashtag2)
    
del dico_tweet["#doctoctoc"]
del dico_tweet["#doctoctoc:"]
del dico_tweet["#doctoctoc,"]

del dico_retweet["#doctoctoc"]
del dico_retweet["#doctoctoc:"]
del dico_retweet["#doctoctoc,"]

# %%
import operator
sorted_dico_tweet = sorted(dico_tweet.items(), key=operator.itemgetter(1), reverse = True ) 
print(sorted_dico_tweet)
# Out:
# [('#docstoctoc', 17), ('#idetoctoc', 11), ('#covid19', 10), ('#covid', 8), ('#teamkine', 8), ('#pharmatoctoc', 7), ('#cardiotoctoc', 5), ('#covid_19', 4), ('#teamkiné', 4), ('#teampharma', 4), ('#diagnostic', 4), ('#', 4), ('#doctoctoc?', 3), ('#diagnostics', 3), ('#sftoctoc', 3), ('#help', 3), ('#installation', 3), ('#mgtoctoc', 2), ('#psytoctoc', 2), ('#vaccin', 2), ('#legal', 2), ('#medecine', 2), ('#ecni2020', 2), ('#fakemed', 2), ('#ide', 2), ('#doctoctoc.', 2), ('#apresj60', 2), ('#these', 2), ('#certifalacon', 2), ('#exercice', 2), ('#pain', 2), ('#neurotoctoc', 2), ('#labotoctoc', 2), ('#raslablouse', 2), ('#medg', 2), ('#covid__19', 2), ('#elbeuf', 2), ('#reading', 2), ('#havefun', 2), ('#breakout', 2), ('#coffee', 2), ('#staygold', 2), ('#haveabreak', 2), ('#positiveenergy', 2), ('#books', 2), ('#healthylifemary', 2), ('#memories', 2), ('#doon', 2), ('#quiz', 2), ('#notmyresponsibility', 1), ('#ccp', 1), ('#organizetowin', 1), ('#covidiots', 1), ('#covididiots', 1), ('#covi
# ...

# %%
sorted_dico_tweet[2]
# Out:
# ('#covid19', 10)

# %%
a=list(sorted_dico_tweet[2])
a[1]=22

# %%
sorted_dico_tweet[2]=tuple(a)

# %%
del sorted_dico_tweet[3]
del sorted_dico_tweet[6]

# %%
sorted_dico_tweet
# Out:
# [('#docstoctoc', 17),
#  ('#idetoctoc', 11),
#  ('#covid19', 22),
#  ('#teamkine', 8),
#  ('#pharmatoctoc', 7),
#  ('#cardiotoctoc', 5),
#  ('#teamkiné', 4),
#  ('#teampharma', 4),
#  ('#diagnostic', 4),
#  ('#', 4),
#  ('#doctoctoc?', 3),
#  ('#diagnostics', 3),
#  ('#sftoctoc', 3),
#  ('#help', 3),
#  ('#installation', 3),
#  ('#mgtoctoc', 2),
#  ('#psytoctoc', 2),
#  ('#vaccin', 2),
#  ('#legal', 2),
#  ('#medecine', 2),
#  ('#ecni2020', 2),
#  ('#fakemed', 2),
#  ('#ide', 2),
#  ('#doctoctoc.', 2),
#  ('#apresj60', 2),
#  ('#these', 2),
#  ('#certifalacon', 2),
#  ('#exercice', 2),
#  ('#pain', 2),
#  ('#neurotoctoc', 2),
#  ('#labotoctoc', 2),
#  ('#raslablouse', 2),
#  ('#medg', 2),
#  ('#covid__19', 2),
#  ('#elbeuf', 2),
#  ('#reading', 2),
#  ('#havefun', 2),
#  ('#breakout', 2),
#  ('#coffee', 2),
#  ('#staygold', 2),
#  ('#haveabreak', 2),
#  ('#positiveenergy', 2),
#  ('#books', 2),
#  ('#healthylifemary', 2),
#  ('#memories', 2),
#  ('#doon', 2),
#  ('#quiz', 2),
# ...

# %%
def num(M):
    return M[1]

aff = sorted(sorted_dico_tweet, key=num, reverse= True)

# %%
#import operator
#sorted_dico_tweet = sorted(sorted_dico_tweet.items(), key=operator.itemgetter(1), reverse = True ) 
#print(sorted_dico_tweet)

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pip 
# Valeurs du graphe
valeurs_y = []
valeurs_x = []
n = 0

for key in aff :
    #print(key)

    if (n < 9): 
     valeurs_x.append(key[0])
     valeurs_y.append(key[1])
    else : 
         break
    n=n+1

# %%
# seaborn countplot on the top 10 hashtags
plt.figure(figsize=(30,8))
sns.set_palette('PuBuGn_d')
sns.barplot(x = valeurs_x, y = valeurs_y)
plt.title('Barplot of Top ' + str(n) + ' Hashtags used')
plt.xlabel('Hashtags')
plt.ylabel('Frequency')
plt.show()

# %%
import operator
sorted_dico_retweet = sorted(dico_retweet.items(), key=operator.itemgetter(1), reverse = True ) 
print(sorted_dico_retweet)
print(dico_retweet)
# Out:
# [('#idetoctoc', 11), ('#covid19', 8), ('#pharmatoctoc', 7), ('#docstoctoc', 5), ('#teamkine', 4), ('#teamkiné', 3), ('#legal', 2), ('#psytoctoc', 2), ('#medecine', 2), ('#covid', 2), ('#covid_19', 2), ('#certifalacon', 2), ('#sftoctoc', 2), ('#elbeuf', 2), ('#quiz', 2), ('#certificats', 1), ('#pratique', 1), ('#cvrmtpouruneamie', 1), ('#msu', 1), ('#clubhouse', 1), ('#newbell', 1), ('#compiègne', 1), ('#oise', 1), ('#raoultpascontent', 1), ('#arminvanbuuren', 1), ('#blahblahblah', 1), ('#soon', 1), ('#nightvibes', 1), ('#nightparty', 1), ('#nightclubs', 1), ('#djm4rs', 1), ('#chocolate', 1), ('#followｍe', 1), ('#tiktok', 1), ('#om', 1), ('#gastroenterologie', 1), ('#internat', 1), ('#ecni2020', 1), ('#vih', 1), ('#allaitementcontreindiqué', 1), ('#polymédication', 1), ('#déprescription', 1), ('#', 1), ('#fakemed', 1), ('#remplatoctoc', 1), ('#phobieadministrative', 1), ('#doctoctoc.', 1), ('#gynecotoctoc', 1), ('#profbashing', 1), ('#mercilesprofs', 1), ('#these', 1), ('#médecinegéné
# ...

# %%
sorted_dico_retweet[1]
# Out:
# ('#covid19', 10)

# %%
b=list(sorted_dico_retweet[1])
b[1]=12

# %%
sorted_dico_retweet[1]=tuple(b)

# %%
del sorted_dico_retweet[9]
del sorted_dico_retweet[9]

# %%
sorted_dico_retweet
# Out:
# [('#idetoctoc', 11),
#  ('#covid19', 12),
#  ('#pharmatoctoc', 7),
#  ('#docstoctoc', 5),
#  ('#teamkine', 4),
#  ('#teamkiné', 3),
#  ('#legal', 2),
#  ('#psytoctoc', 2),
#  ('#medecine', 2),
#  ('#certifalacon', 2),
#  ('#sftoctoc', 2),
#  ('#elbeuf', 2),
#  ('#quiz', 2),
#  ('#certificats', 1),
#  ('#pratique', 1),
#  ('#cvrmtpouruneamie', 1),
#  ('#msu', 1),
#  ('#clubhouse', 1),
#  ('#newbell', 1),
#  ('#compiègne', 1),
#  ('#oise', 1),
#  ('#raoultpascontent', 1),
#  ('#arminvanbuuren', 1),
#  ('#blahblahblah', 1),
#  ('#soon', 1),
#  ('#nightvibes', 1),
#  ('#nightparty', 1),
#  ('#nightclubs', 1),
#  ('#djm4rs', 1),
#  ('#chocolate', 1),
#  ('#followｍe', 1),
#  ('#tiktok', 1),
#  ('#om', 1),
#  ('#gastroenterologie', 1),
#  ('#internat', 1),
#  ('#ecni2020', 1),
#  ('#vih', 1),
#  ('#allaitementcontreindiqué', 1),
#  ('#polymédication', 1),
#  ('#déprescription', 1),
#  ('#', 1),
#  ('#fakemed', 1),
#  ('#remplatoctoc', 1),
#  ('#phobieadministrative', 1),
# ...

# %%
def num(M):
    return M[1]

afficher = sorted(sorted_dico_retweet, key=num, reverse= True)

# %%
valeurs_y = []
valeurs_x = []
n = 0

for key in afficher:
    #print(key)

    if (n < 10): 
     valeurs_x.append(key[0])
     valeurs_y.append(key[1])
    else : 
         break
    n=n+1

# %%
# seaborn countplot on the top 30 hashtags
plt.figure(figsize=(30,8))
sns.set_palette('PuBuGn_d')
sns.barplot(x = valeurs_x, y = valeurs_y)
plt.title('Barplot of Top ' + str(n) + ' Hashtags used')
plt.xlabel('Hashtags')
plt.ylabel('Frequency')
plt.show()

# %%
df.to_excel("data_finale.xls", index = False)

# %%
location = df['location']
print('No. of distinct locations listed by twitter users is:', len(location.value_counts()))
unique_locations = location.value_counts()

# Remove n.a.
unique_locations = pd.DataFrame({'location': unique_locations.index,
                                'count': unique_locations.values})
unique_locations.drop(0, inplace = True)

# See top few locations
unique_locations.sort_values(by = 'count', ascending = False).head(20)
# Out:
# No. of distinct locations listed by twitter users is: 270
#                     location  count
# 1                     Nantes     46
# 2              Paris, France     24
# 3                      Paris     17
# 4      Ile-de-France, France     16
# 5                  Marseille     16
# 6           Lorraine, France     12
# 7             Vedène, France     11
# 8               with my cats     11
# 9             Nantes, France     10
# 11             Lille, France      9
# 10      Ça dépend ça dépasse      9
# 12               petaouchnok      8
# 13     Jean Boudin Président      8
# 14                      Mars      8
# 15       Montpellier ,France      8
# 16             Chocolatinie       8
# 17      Au nord ouest du Sud      7
# 18   La tête dans les nuages      7
# 23               De la burle      6
# 25  Vendée, Pays de la Loire      6

# %%
hk_chinese_word = unique_locations.iloc[1,0]

# Obtain the row index of locations that contain hong kong:
ind_1 = unique_locations[unique_locations['location'] == 'Lille, France'].index.values[0]
ind_2 = unique_locations[unique_locations['location'] == '@Earth 🌍'].index.values[0]
list_ind = [ind_1,ind_2]

# Drop these rows from unique_locations
unique_loc_temp = unique_locations.drop(list_ind)

# %%
count = pd.to_numeric(unique_loc_temp['count'])
unique_loc_temp['count'] = count
unique_loc_temp = unique_loc_temp.head(20)

# %%
# Plot a bar plot
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16,13))
sns.set_palette('PuBuGn_d')
sns.barplot(x = 'count', y = 'location', orient = 'h',data = unique_loc_temp)
plt.xlabel('Count')
plt.ylabel('Location')
plt.title('Top 20 Locations')
plt.show()

# %%
df
# Out:
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   Hello #DocTocToc #Rachiphiles #TeamKiné :\nPte...   911146402289537024
# 41   Bonjour à tous ! Néo interne déçu de mes ECNi,...            577992136
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #DocTocToc #KineTocToc \nJ’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
df["description"] = df["description"].str.lower()
dico = ("MG","mg","Médcin","médecin","medecin","med","Dr", "docteure", "docteur", "doc", "généraliste", "interne", 
        "professionnel",
        "soigant","interne",
        "internat", "remplaçant", "pédiatre", "msu","médecingé","dr","médicienne"
        "img","biologiste-médicale","rhumologue", "psychiatrie"," psychiatre")
requete = '|'.join(dico)
df["aray1"] = pd.np.where(df["description"].str.contains(requete),1,0)
medcin= df[df["aray1"]==1]
medcin

#medecin sur la base des descriptions
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df["user.name"] = df["user.name"].str.lower()
dico = ("MG","mg","Médcin","médecin","medecin","med","Dr", "docteure", "docteur", "doc", "généraliste", "interne", 
        "professionnel",
        "soigant","interne",
        "internat", "remplaçant", "pédiatre", "msu","médecingé","dr","médicienne"
        "img","biologiste-médicale","rhumologue", "psychiatrie"," psychiatre")
requete = '|'.join(dico)
df["aray2"] = pd.np.where(df["user.name"].str.contains(requete),1,0)
medcin_user= df[df["aray2"]==1]
medcin_user

#medecin par user.name
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   Hello #DocTocToc #Rachiphiles #TeamKiné :\nPte...   911146402289537024
# 41   Bonjour à tous ! Néo interne déçu de mes ECNi,...            577992136
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #DocTocToc #KineTocToc \nJ’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
df["user.screen_name"] = df["user.screen_name"].str.lower()
dico = ("MG","mg","Médcin","médecin","medecin","med","Dr", "docteure", "docteur", "doc", "généraliste", "interne", 
        "professionnel","cardiologie","cardio"
        "soigant","externe",
        "internat", "remplaçant", "pédiatre","pédiâtre","msu","médecingé","dr","médicienne"
        "img","biologiste-médicale","rhumologue", "psychiatrie"," psychiatre","dentiste","gériatre")
requete = '|'.join(dico)
df["aray3"] = pd.np.where(df["user.screen_name"].str.contains(requete),1,0)
medcin_user_screen= df[df["aray3"]==1]
medcin_user_screen
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   Hello #DocTocToc #Rachiphiles #TeamKiné :\nPte...   911146402289537024
# 41   Bonjour à tous ! Néo interne déçu de mes ECNi,...            577992136
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #DocTocToc #KineTocToc \nJ’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
df.to_excel("data_médecins_finale.xls", index = False)

# %%
df["user.screen_name"] = df["user.screen_name"].str.lower()
dico = ("pharm", "pharma", "kiné", "orthoptiste", "infirmière", "secrétaire-médicale", "pharmacien-biologiste",
        "pharmacien", "pharmacienne","infirmier","mk","sage femme","sage-femme","ide","idel","soignant")
requete = '|'.join(dico)
df["aray4"] = pd.np.where(df["user.screen_name"].str.contains(requete),1,0)
medcin_user_screen= df[df["aray4"]==1]
medcin_user_screen

#autres professionel de la santé
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df["description"] = df["description"].str.lower()
dico = ("pharm", "pharma", "kiné", "orthoptiste", "infirmière", "secrétaire-médicale", "pharmacien-biologiste",
        "pharmacien", "pharmacienne","infirmier","mk","sage femme","sage-femme","ide","idel","soignant")
requete = '|'.join(dico)
df["aray5"] = pd.np.where(df["description"].str.contains(requete),1,0)
medcin_user_screen= df[df["aray5"]==1]
medcin_user_screen
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df["user.name"] = df["user.name"].str.lower()
dico = ("pharm", "pharma", "kiné", "orthoptiste", "infirmière", "secrétaire-médicale", "pharmacien-biologiste",
        "pharmacien", "pharmacienne","infirmier","mk","sage femme","sage-femme","ide","idel","soignant")
requete = '|'.join(dico)
df["aray6"] = pd.np.where(df["user.name"].str.contains(requete),1,0)
medcin_user_screen= df[df["aray6"]==1]
medcin_user_screen
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df
# Out:
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   Hello #DocTocToc #Rachiphiles #TeamKiné :\nPte...   911146402289537024
# 41   Bonjour à tous ! Néo interne déçu de mes ECNi,...            577992136
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #DocTocToc #KineTocToc \nJ’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
df.drop(['fav', 'tweet coordinate','source','in_reply_to_status_id','statuses_count','friends_count','tweet_id','favourites_count','url'], axis = 1, inplace = True)
df
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   Hello #DocTocToc #Rachiphiles #TeamKiné :\nPte...   911146402289537024
# ...

# %%
df.drop(['followers_count','location','langue','verified','contributors','text','in_reply_to_screen_name','in_reply_to_user_id','in_reply_to_user_id_str','retweet_count'], axis = 1, inplace = True)
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df
# Out:
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   Hello #DocTocToc #Rachiphiles #TeamKiné :\nPte...   911146402289537024
# 41   Bonjour à tous ! Néo interne déçu de mes ECNi,...            577992136
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #DocTocToc #KineTocToc \nJ’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
df.drop(['aray1','aray2','aray3'], axis = 1, inplace = True)
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df
# Out:
#                                                  tweet              user_id  \
# 0    L’alcool à brûler est-il efficace contre le CO...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #DocTocToc Qu’en pensez vous? Teritoire latéra...            607137892
# 531  #doctoctoc\nBonjour, une jeûne de 19 ans sans ...           4774346355
# 532  Et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   Hello #DocTocToc #Rachiphiles #TeamKiné :\nPte...   911146402289537024
# 41   Bonjour à tous ! Néo interne déçu de mes ECNi,...            577992136
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #DocTocToc #KineTocToc \nJ’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
df.to_excel("data_autre_prof_final.xls", index= False)

# %%
df.tweet = df.tweet.str.lower()
dico = ("\?","question", "coup","quelqu-un", "aurait-il","est_ce", "help", "paumé","aide", "idée")
requete = '|'.join(dico)
df["aray"] = pd.np.where(df.tweet.str.contains(requete),1,0)
no_question = df[df["aray"]==1]
no_question
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   after removing the cwd from sys.path.
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
no_question.drop(['aray4','aray5','aray6'], axis = 1, inplace = True)
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
no_question
# Out:
#                                                  tweet              user_id  \
# 0    l’alcool à brûler est-il efficace contre le co...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #doctoctoc qu’en pensez vous? teritoire latéra...            607137892
# 532  et du coup on fait arrêt ou certificat de mise...           2742776128
# 534                                                NaN            383802907
# ..                                                 ...                  ...
# 39   une idée pour le 14 les docs de ma tl #doctoct...   908536419064233985
# 40   hello #doctoctoc #rachiphiles #teamkiné :\npte...   911146402289537024
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #doctoctoc #kinetoctoc \nj’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
from datetime import datetime
import re
ind_to_drop = []
date = []

# First find out which 'tweetcreatedts' is not a string or in other weird formats
for i in range(0, len(df)):
    ith_date_str = df.iloc[i,:]['created_at']
    ith_match = re.search(r'\d{4}-\d{2}-\d{2}', ith_date_str)
    if ith_match == None:
        ind_to_drop.append(i)
    else:
        continue

# %%
# Create a new list of datetime date objects from the tweets:
import re
for i in range(0, len(df)):
    ith_date_str = df.iloc[i, :]['created_at']
    ith_match = re.search(r'\d{4}-\d{2}-\d{2}', ith_date_str)
    ith_date = datetime.strptime(ith_match.group(), '%Y-%m-%d').date()
    
    date.append(ith_date)
    
# Size of list 'date'
print('Len of date list: ', len(date))
# Out:
# Len of date list:  1428

# %%
# Append 'date' to dataframe 'data' as 'dt_date' aka 'datetime_date'
df['dt_date'] = date
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['dt_date'].value_counts()
# Out:
# 2020-06-24    42
# 2020-07-17    42
# 2020-06-19    41
# 2020-06-03    40
# 2020-07-08    39
# 2020-05-27    38
# 2020-06-10    36
# 2020-07-01    36
# 2020-07-10    35
# 2020-07-07    34
# 2020-07-20    34
# 2020-06-02    33
# 2020-06-05    33
# 2020-07-13    33
# 2020-06-22    32
# 2020-06-12    32
# 2020-05-26    32
# 2020-07-06    32
# 2020-07-16    31
# 2020-06-25    30
# 2020-06-23    30
# 2020-07-03    29
# 2020-05-28    29
# 2020-06-26    28
# 2020-06-11    28
# 2020-06-04    28
# 2020-06-18    28
# 2020-06-15    28
# 2020-06-08    27
# 2020-06-30    27
# 2020-07-11    25
# 2020-06-06    24
# 2020-06-27    24
# 2020-07-18    23
# 2020-06-29    23
# 2020-07-15    23
# 2020-05-29    23
# 2020-06-16    22
# 2020-07-02    21
# 2020-06-14    19
# 2020-07-04    19
# 2020-06-28    19
# 2020-06-17    18
# 2020-06-09    18
# 2020-07-05    16
# 2020-06-21    15
# 2020-05-30    15
# 2020-06-13    14
# 2020-06-20    13
# 2020-05-31    12
# 2020-07-14    12
# 2020-06-07    10
# ...

# %%
df
# Out:
#                                                  tweet              user_id  \
# 0    l’alcool à brûler est-il efficace contre le co...   976744477745348608
# 529                                                NaN   862359205889617920
# 530  #doctoctoc qu’en pensez vous? teritoire latéra...            607137892
# 531  #doctoctoc\nbonjour, une jeûne de 19 ans sans ...           4774346355
# 532  et du coup on fait arrêt ou certificat de mise...           2742776128
# ..                                                 ...                  ...
# 40   hello #doctoctoc #rachiphiles #teamkiné :\npte...   911146402289537024
# 41   bonjour à tous ! néo interne déçu de mes ecni,...            577992136
# 43   #doctoctoc on a une date de fin pour l'exo3 de...            262592073
# 44                                                 NaN  1245641055967436800
# 45   #doctoctoc #kinetoctoc \nj’ai une sciatique qu...  1181543629422247936
#
# ...

# %%
import numpy as np
unique_date = np.unique(date)
print('Unique dates available in this dataset are:')
print(unique_date)
# Out:
# Unique dates available in this dataset are:
# [datetime.date(2020, 5, 11) datetime.date(2020, 5, 25)
#  datetime.date(2020, 5, 26) datetime.date(2020, 5, 27)
#  datetime.date(2020, 5, 28) datetime.date(2020, 5, 29)
#  datetime.date(2020, 5, 30) datetime.date(2020, 5, 31)
#  datetime.date(2020, 6, 2) datetime.date(2020, 6, 3)
#  datetime.date(2020, 6, 4) datetime.date(2020, 6, 5)
#  datetime.date(2020, 6, 6) datetime.date(2020, 6, 7)
#  datetime.date(2020, 6, 8) datetime.date(2020, 6, 9)
#  datetime.date(2020, 6, 10) datetime.date(2020, 6, 11)
#  datetime.date(2020, 6, 12) datetime.date(2020, 6, 13)
#  datetime.date(2020, 6, 14) datetime.date(2020, 6, 15)
#  datetime.date(2020, 6, 16) datetime.date(2020, 6, 17)
#  datetime.date(2020, 6, 18) datetime.date(2020, 6, 19)
#  datetime.date(2020, 6, 20) datetime.date(2020, 6, 21)
#  datetime.date(2020, 6, 22) datetime.date(2020, 6, 23)
#  datetime.date(2020, 6, 24) datetime.date(2020, 6, 25)
# ...

# %%
top_user_df = pd.DataFrame(columns = ['username', 'noTweets', 'noFollowers', 'dt_date'])

# Convert datatype of 'totaltweets' to numeric
pd.to_numeric(df['followers_count'])

for ith_date in unique_date:
    print('Current loop: ', ith_date)
    
    temp = df[df['dt_date'] == ith_date]
    
    # pd.DataFrame - count number of tweets tweeted in that day - noTweets
    temp_noTweets = temp.groupby(['user.name']).size().reset_index(name = 'noTweets').sort_values(by = 'user.name', ascending = False)
    
    # pd.Series - count max followers - might fluctuate during the day
    temp_noFollowing = temp.groupby(['user.name'])['followers_count'].max().reset_index(name = 'noFollowers').sort_values(by = 'user.name', ascending = False)['noFollowers']
    
    # *** NOT WORKING
    # pd.Series - count max totaltweets - might fluctuate during the day. Note this is historical total number of tweets ever since the user is created.
    # temp_noTotaltweets = temp.groupby(['username'])['totaltweets'].max().reset_index(name = 'noTotaltweets').sort_values(by = 'username', ascending = False)['noTotaltweets']
    
    # Concat series to temp_noTweets, which will be the main df
    final = pd.concat([temp_noTweets, temp_noFollowing], axis = 1) # add as columns
    final['dt_date'] = ith_date
    
    print(final)
    
    # Append 'final' dataframe to top_user_df
    top_user_df = pd.concat([top_user_df, final])
# Out:
# Current loop:  2020-05-11
#              user.name  noTweets  noFollowers     dt_date
# 0  𝓝𝓮𝓫𝓾𝓵𝓮𝓾𝓼𝓮  (public)         1          266  2020-05-11
# Current loop:  2020-05-25
#           user.name  noTweets  noFollowers     dt_date
# 3  marguerite dupré         1           42  2020-05-25
# 2           Dr Cyno         1         1468  2020-05-25
# 1                Dr         1           19  2020-05-25
# 0     Docteure Gécé         1         5289  2020-05-25
# Current loop:  2020-05-26
#                                         user.name  noTweets  noFollowers  \
# 29                               ᴅᴏᴄᴛᴇᴜʀᴍᴀᴛʜɪᴇᴜ 😷         1         3227
# 28                                petitdocenherbe         1          166
# 27                                 odilehenriette         1         1644
# 26                               marguerite dupré         2           42
# 25                                       jlclouet         1          317
# ...

# %%
# To change the number of users, adjust the value in head()
# top_user_df.set_index(['dt_date', 'username']).sort_values(by = ['dt_date','noTweets'], ascending = False)
import matplotlib.pyplot as plt
user_most_tweets_df = top_user_df.sort_values(by = ['dt_date', 'noTweets'], 
                                              ascending = False, axis = 0).groupby('dt_date').head(3)

# Extract 'days' out of dt_date so we can plot a scatterplot
# Will return an int:
user_most_tweets_df['dayofMai'] = user_most_tweets_df['dt_date'].apply(lambda x: x.day)
user_most_tweets_df['noTweets'] = user_most_tweets_df['noTweets'].astype(int)

# Plot 2 subplots
# 1st subplot - show who are the users who tweeted the most
# 2nd subplot - trend in number of tweets
f, axes = plt.subplots(2, 1, figsize = (20,20))
f = sns.scatterplot(x = 'dayofMai', y = 'noTweets', hue = 'user.name', 
                    data = user_most_tweets_df, size = 'noFollowers', sizes = (250, 1250), alpha = 0.75, ax = axes[0])
sns.lineplot(x = 'dayofMai', y = 'noTweets', data = user_most_tweets_df, markers = True)

# Axes and titles for each subplot
# First subplot
axes[0].set_xlabel('Day in Mai')
axes[0].set_ylabel('No. of Tweets')
axes[0].set_title('Most no. of tweets daily')

# Legends for first subplot
box = f.get_position()
f.set_position([box.x0, box.y0, box.width * 1.0, box.height]) # resize position

# Put a legend to the right side
f.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=4)

# Second subplot
axes[1].set_xlabel('Date')
axes[1].set_ylabel('No. of Tweets')
axes[1].set_title('Trend of no. of tweets by top users')

#Top des utilisateurs avec le plus grand nombre de tweets au quotidien

plt.show()
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55357 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56887 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9994 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 57339 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
user_most_followers_daily = top_user_df.sort_values(by = ['dt_date', 'noFollowers'],
                                                    ascending = False, axis = 0).groupby('dt_date').head(5)
print(user_most_followers_daily)

# Extract 'days' out of dt_date so we can plot a scatterplot
# Will return an int:
#Acitivité autour des comptes ayant le plus de followers

user_most_followers_daily['dayofMai'] = user_most_followers_daily['dt_date'].apply(lambda x: x.day)
user_most_followers_daily['noFollowers'] = user_most_followers_daily['noFollowers'].astype(int)
# Out:
#    username noTweets noFollowers     dt_date  \
# 2       NaN        1        1992  2020-07-21
# 0       NaN        1         158  2020-07-21
# 1       NaN        1          98  2020-07-21
# 13      NaN        1       14909  2020-07-20
# 15      NaN        1       12745  2020-07-20
# ..      ...      ...         ...         ...
# 0       NaN        1        5289  2020-05-25
# 2       NaN        1        1468  2020-05-25
# 3       NaN        1          42  2020-05-25
# 1       NaN        1          19  2020-05-25
# 0       NaN        1         266  2020-05-11
#
#                              user.name
# 2                               Maneki
# 0        Dr Marmotte Verte- No#FakeMed
# 1                                    F
# 13  Jean-Jacques Fraslin - No #FakeMed
# 15                                KPMG
# ..                                 ...
# 0                        Docteure Gécé
# 2                              Dr Cyno
# 3                     marguerite dupré
# ...

# %%
import matplotlib.pyplot as plt
f, axes = plt.subplots(1, 1, figsize = (15,10))
f = sns.scatterplot(x = 'dayofMai', y = 'noTweets', hue = 'user.name',
                    data = user_most_followers_daily, size = 'noFollowers', sizes=(15, 1000))

# Axes and titles for each subplot
# First subplot
axes.set_xlabel('Day in Nov')
axes.set_ylabel('No. of Tweets')
axes.set_title('Daily activity of users with most number of followers')

# Legends for first subplot
box = f.get_position()
f.set_position([box.x0, box.y0, box.width * 1, box.height]) # resize position

# Put a legend to the right side
f.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=3)
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55357 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56887 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55358 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56954 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55349 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
df.tweet = df.tweet.str.lower()
dico = ("\?","question", "coup","aurait-il","est-ce","comment","quelqu-un", "aide", "idée","paumé","help")
requete = '|'.join(dico)
df["aray1"] = pd.np.where(df.tweet.str.contains(requete),1,0)
nombre_question = df[df["aray1"]==1]
nombre_question
# Out:
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   after removing the cwd from sys.path.
# C:\Users\Camille KPLE\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
date = nombre_question['dt_date']
print('No. of distinct locations listed by twitter users is:', len(nombre_question['user.name'].value_counts()))
unique_date = df['dt_date'].value_counts()

# Remove n.a.
unique_date = pd.DataFrame({'date': unique_date.index,
                                'no_question': unique_date.values})
unique_date.drop(0, inplace = True)

# See top few locations
unique_date.sort_values(by = 'no_question', ascending = False).head(20)
# Out:
# No. of distinct locations listed by twitter users is: 610
#           date  no_question
# 1   2020-07-17           42
# 2   2020-06-19           41
# 3   2020-06-03           40
# 4   2020-07-08           39
# 5   2020-05-27           38
# 6   2020-06-10           36
# 7   2020-07-01           36
# 8   2020-07-10           35
# 9   2020-07-07           34
# 10  2020-07-20           34
# 11  2020-06-02           33
# 12  2020-06-05           33
# 13  2020-07-13           33
# 16  2020-05-26           32
# 17  2020-07-06           32
# 14  2020-06-22           32
# 15  2020-06-12           32
# 18  2020-07-16           31
# 19  2020-06-25           30
# 20  2020-06-23           30

# %%
import matplotlib.pyplot as plt
user_most_tweets_df = unique_date.sort_values(by = ['date', 'no_question'],
                                              ascending = False, axis = 0).groupby('date').head(5)
# Extract 'days' out of dt_date so we can plot a scatterplot
# Will return an int:
user_most_tweets_df['dayofMai'] = user_most_tweets_df['date'].apply(lambda x: x.day)
user_most_tweets_df['noTweets'] = user_most_tweets_df['no_question'].astype(int)
f, axes = plt.subplots(2, 1, figsize = (20,20))
f = sns.scatterplot(x = 'dayofMai', y = 'no_question', data = user_most_tweets_df,
                    sizes = (250, 1250), alpha = 0.75, ax = axes[0])
sns.lineplot(x = 'dayofMai', y = 'no_question', data = user_most_tweets_df, markers = True)

# Axes and titles for each subplot
# First subplot
axes[0].set_xlabel('Day in Mai')
axes[0].set_ylabel('No. of Tweets')
axes[0].set_title('Most no. of tweets daily')

# Legends for first subplot
box = f.get_position()
f.set_position([box.x0, box.y0, box.width * 1.0, box.height]) # resize position

# Put a legend to the right side
f.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=4)

# Second subplot
axes[1].set_xlabel('Date')
axes[1].set_ylabel('No. of Tweets question')
axes[1].set_title('Distribution nombre de question sur le temps')


plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
non_question = df[df["aray1"]==0]
non_question
# Out:
#                                                  tweet              user_id  \
# 531  #doctoctoc\nbonjour, une jeûne de 19 ans sans ...           4774346355
# 533  #covid19 #notmyresponsibility #ccp #organizeto...  1249513600781127680
# 537  #teamkiné\n#doctoctoc\n\namis pds vulgarisateu...   911146402289537024
# 542  coucou twitter! le département de seine-mariti...           2255120910
# 544  @drgroquik @asclepios_yt ouais jsais bien j'en...           1638119190
# ..                                                 ...                  ...
# 78   #doctoctoc f17 ans anorexie suivi par thérapeu...  1064541529623199744
# 9    the gaint fibroadenoma is something very scarr...  1137280906899668992
# 32                             #doctoctoc #recherchemg             59157716
# 36                  #doctoctoc https://t.co/dnyv342gvq            810868321
# 41   bonjour à tous ! néo interne déçu de mes ecni,...            577992136
#
# ...

# %%
date = non_question['dt_date']
print('No. of distinct locations listed by twitter users is:', len(non_question['user.name'].value_counts()))
unique_date_noquestion = non_question['dt_date'].value_counts()

# Remove n.a.
unique_date_noquestion = pd.DataFrame({'date': unique_date_noquestion.index,
                                'non_question': unique_date_noquestion.values})
unique_date_noquestion.drop(0, inplace = True)

# See top few locations
unique_date_noquestion.sort_values(by = 'non_question', ascending = False).head(10)
# Out:
# No. of distinct locations listed by twitter users is: 105
#           date  non_question
# 1   2020-05-27             7
# 3   2020-07-08             6
# 2   2020-06-05             6
# 4   2020-06-24             5
# 5   2020-06-27             5
# 6   2020-06-08             4
# 7   2020-07-20             4
# 8   2020-06-30             4
# 9   2020-06-03             4
# 10  2020-05-26             4

# %%
import matplotlib.pyplot as plt
user_most_tweets_df = unique_date_noquestion.sort_values(by = ['date', 'non_question'],
                                              ascending = False, axis = 0).groupby('date').head(5)
# Extract 'days' out of dt_date so we can plot a scatterplot
# Will return an int:
user_most_tweets_df['dayofMai'] = user_most_tweets_df['date'].apply(lambda x: x.day)
user_most_tweets_df['noTweets'] = user_most_tweets_df['non_question'].astype(int)
f, axes = plt.subplots(2, 1, figsize = (20,20))
f = sns.scatterplot(x = 'dayofMai', y = 'non_question', data = user_most_tweets_df,
                    sizes = (250, 1250), alpha = 0.75, ax = axes[0])
sns.lineplot(x = 'dayofMai', y = 'non_question', data = user_most_tweets_df, markers = True)

# Axes and titles for each subplot
# First subplot
axes[0].set_xlabel('Day in Mai')
axes[0].set_ylabel('No. of Tweets')
axes[0].set_title('Most no. of tweets daily')

# Legends for first subplot
box = f.get_position()
f.set_position([box.x0, box.y0, box.width * 1.0, box.height]) # resize position

# Put a legend to the right side
f.legend(loc='center right', bbox_to_anchor=(1.5, 0.5), ncol=4)

# Second subplot
axes[1].set_xlabel('Date')
axes[1].set_ylabel('No. of Tweets non_question')
axes[1].set_title('Distribution non question sur le temps')


plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
no_question.to_excel("data_tweets_questions.xls", index= False)
